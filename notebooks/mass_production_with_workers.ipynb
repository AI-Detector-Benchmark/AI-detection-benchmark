# %%
""" The system attempts to test the models via OpenRouter in batches, one after the other. If the API does not receive any errors (429, 403, 404), 
it increases the number of requests. If it receives an error, it decreases it. Then it moves on to the next model."""
# Out:
#   Cell In[2], line 2
#     it increases the number of requests. If it receives an error, it decreases it. Then it moves on to the next model.
#        ^
# SyntaxError: invalid syntax

# %%
# %pip install openai tqdm pandas openpyxl pyyaml -q

# %%
import os
import sys
import json
import time
import pandas as pd
import threading
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timezone
from tqdm.auto import tqdm
from openai import OpenAI
import csv
